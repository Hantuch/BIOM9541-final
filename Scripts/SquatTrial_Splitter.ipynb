# %%
import pandas as pd
import os

# Read .trc files
mot_files = ['Hanif_Shallow_2_5_grf.mot', 'Hanif_Shallow_5_0_grf.mot', 'Hanif_Shallow_7_5_grf.mot']
base_path = os.path.join('..', 'Vicon Data', 'Shallow Squat','ID','GRF')

timeranges = [
    [                
        (0.2, 1.7),
        (2.2, 3.7),
        (4.2, 5.7),
    ],
    [                
        (0.2, 2.2),
        (2.3, 4.3),
        (4.4, 6.5),
    ],
    [                
        (0.8, 3.1),
        (3.4, 5.8),
        (6.1, 8.5),
    ]
]

for mot_file, timerange in zip(mot_files, timeranges):

    mot_path = os.path.join(base_path, 'Continuous', mot_file)


    with open(mot_path, 'r') as f:
        lines = f.readlines()

    # find header line (first line starting with 'time' or 'Time')
    header_idx = None
    for i, line in enumerate(lines):
        if line.strip().lower().startswith("time"):
            header_idx = i
            break

    header = lines[:header_idx]

    # Read numeric data after header
    df = pd.read_csv(mot_path, sep='\t', skiprows=header_idx, header=0)
    print(df)

    # -------------------------
    # Split by time ranges
    for i, (start, end) in enumerate(timerange, 1):
        sub_df = df[(df['time'] >= start) & (df['time'] <= end)].copy()

        nRows = sub_df.shape[0]
        header[2] = f"nRows={nRows}\n"
        header_text = ''.join(header)

        out_path = os.path.join(base_path, f"{i}_{mot_file}")
        with open(out_path, 'w') as f:
            f.write(header_text)
            sub_df.to_csv(f, sep='\t', index=False, float_format='%.6f')
        print(f"Saved {out_path} ({sub_df.shape[0]} frames, {start}-{end}s)")

    print("All done!")
# Out:
#        time  right_ground_force_vx  right_ground_force_vy  \
# 0     0.000                2.71527                259.713
# 1     0.005                2.61858                258.521
# 2     0.010                2.87684                258.786
# 3     0.015                2.75743                256.911
# 4     0.020                2.86224                258.269
# ...     ...                    ...                    ...
# 1332  6.660                3.68920                257.132
# 1333  6.665                4.01707                256.304
# 1334  6.670                4.14356                254.945
# 1335  6.675                3.69074                255.955
# 1336  6.680                4.25880                256.668
#
#       right_ground_force_vz  right_ground_force_px  right_ground_force_py  \
# 0                   54.8033               0.216859                    0.0
# 1                   55.5601               0.217068                    0.0
# 2                   55.3078               0.216586                    0.0
# 3                   55.6441               0.216793                    0.0
# 4                   55.2959               0.216214                    0.0
# ...                     ...                    ...                    ...
# 1332                56.7951               0.214939                    0.0
# 1333                56.5322               0.215172                    0.0
# 1334                56.7046               0.214175                    0.0
# 1335                56.8153               0.214525                    0.0
# 1336                57.0639               0.213709                    0.0
#
#       right_ground_force_pz  right_ground_torque_x  right_ground_torque_y  \
# 0                  -1.44315               -16.3194              -0.313992
# 1                  -1.44345               -16.1642              -0.261688
# 2                  -1.44314               -16.2626              -0.211033
# 3                  -1.44302               -16.1724              -0.142362
# 4                  -1.44294               -16.2816              -0.238232
# ...                     ...                    ...                    ...
# 1332               -1.44906               -14.6261               0.427627
# 1333               -1.44863               -14.6887               0.391254
# 1334               -1.44889               -14.5443               0.459878
# 1335               -1.44909               -14.5509               0.487528
# 1336               -1.44799               -14.8730               0.495176
#
#       right_ground_torque_z  left_ground_force_vx  left_ground_force_vy  \
# 0                   4.47106              -5.40114               283.318
# 1                   4.52469              -5.31222               281.798
# 2                   4.40441              -5.39907               283.337
# 3                   4.44824              -5.21870               282.036
# 4                   4.28982              -5.04934               283.127
# ...                     ...                   ...                   ...
# 1332                4.07685              -5.10531               276.917
# 1333                4.11317              -5.14989               276.647
# 1334                3.84222              -5.16412               277.549
# 1335                3.96247              -5.34959               278.692
# 1336                3.74769              -5.55667               279.878
#
#       left_ground_force_vz  left_ground_force_px  left_ground_force_py  \
# 0                 -56.0487              0.238844                   0.0
# 1                 -55.7085              0.239096                   0.0
# 2                 -56.0757              0.238431                   0.0
# 3                 -55.7797              0.238529                   0.0
# 4                 -55.8659              0.238408                   0.0
# ...                    ...                   ...                   ...
# 1332              -57.1184              0.233367                   0.0
# 1333              -56.9967              0.233286                   0.0
# 1334              -57.5903              0.233251                   0.0
# 1335              -57.2152              0.233169                   0.0
# 1336              -57.4231              0.233522                   0.0
#
#       left_ground_force_pz  left_ground_torque_x  left_ground_torque_y  \
# 0                -0.965323               17.7076             -0.126442
# 1                -0.965865               17.7657             -0.164814
# 2                -0.965444               17.7432             -0.156963
# 3                -0.965513               17.6792             -0.143076
# 4                -0.965961               17.8728             -0.166365
# ...                    ...                   ...                   ...
# 1332             -0.965384               17.3252             -0.485771
# 1333             -0.966076               17.5015             -0.564621
# 1334             -0.965362               17.3602             -0.545298
# 1335             -0.965589               17.4959             -0.514633
# 1336             -0.965808               17.6333             -0.490791
#
#       left_ground_torque_z
# 0                 11.52750
# 1                 11.54630
# 2                 11.41330
# 3                 11.38450
# 4                 11.39330
# ...                    ...
# 1332               9.79877
# 1333               9.78273
# 1334               9.80607
# 1335               9.80790
# 1336               9.94917
#
# [1337 rows x 19 columns]
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\1_Hanif_Shallow_2_5_grf.mot (301 frames, 0.2-1.7s)
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\2_Hanif_Shallow_2_5_grf.mot (301 frames, 2.2-3.7s)
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\3_Hanif_Shallow_2_5_grf.mot (301 frames, 4.2-5.7s)
# All done!
#        time  right_ground_force_vx  right_ground_force_vy  \
# 0     0.000              -0.760429                276.508
# 1     0.005              -0.574662                276.538
# 2     0.010              -0.581428                276.213
# 3     0.015              -0.478788                276.371
# 4     0.020              -0.646796                275.380
# ...     ...                    ...                    ...
# 1445  7.225              -3.796530                291.330
# 1446  7.230              -3.378090                289.604
# 1447  7.235              -3.294430                287.815
# 1448  7.240              -3.718670                288.512
# 1449  7.245              -3.959960                287.082
#
#       right_ground_force_vz  right_ground_force_px  right_ground_force_py  \
# 0                   53.9721               0.216648                    0.0
# 1                   54.1006               0.216731                    0.0
# 2                   54.1235               0.216749                    0.0
# 3                   54.0298               0.217123                    0.0
# 4                   53.9648               0.216337                    0.0
# ...                     ...                    ...                    ...
# 1445                55.5952               0.226839                    0.0
# 1446                55.1811               0.227071                    0.0
# 1447                54.8914               0.227661                    0.0
# 1448                54.8808               0.227288                    0.0
# 1449                54.7490               0.228118                    0.0
#
#       right_ground_force_pz  right_ground_torque_x  right_ground_torque_y  \
# 0                  -1.42928               -21.2148              -1.009820
# 1                  -1.42929               -21.2141              -0.929598
# 2                  -1.42929               -21.1876              -1.044860
# 3                  -1.42925               -21.2124              -0.996155
# 4                  -1.42867               -21.2957              -0.918143
# ...                     ...                    ...                    ...
# 1445               -1.42422               -23.8503               0.047126
# 1446               -1.42404               -23.7573               0.156488
# 1447               -1.42398               -23.6268               0.073633
# 1448               -1.42364               -23.7850               0.085313
# 1449               -1.42335               -23.7533               0.054526
#
#       right_ground_torque_z  left_ground_force_vx  left_ground_force_vy  \
# 0                   4.59299              -4.33056               288.086
# 1                   4.63054              -4.56088               288.672
# 2                   4.60792              -4.46406               289.118
# 3                   4.72574              -4.34882               286.932
# 4                   4.50160              -4.90144               287.192
# ...                     ...                   ...                   ...
# 1445                8.17206              -2.38189               278.924
# 1446                8.20712              -2.57987               276.770
# 1447                8.31647              -2.75550               276.328
# 1448                8.23226              -3.15100               274.171
# 1449                8.43845              -3.53140               273.899
#
#       left_ground_force_vz  left_ground_force_px  left_ground_force_py  \
# 0                 -54.5697              0.232650                   0.0
# 1                 -54.5460              0.232663                   0.0
# 2                 -54.5624              0.232145                   0.0
# 3                 -54.2923              0.232536                   0.0
# 4                 -54.2524              0.233112                   0.0
# ...                    ...                   ...                   ...
# 1445              -52.0374              0.233388                   0.0
# 1446              -52.1580              0.234578                   0.0
# 1447              -52.0530              0.234285                   0.0
# 1448              -52.3060              0.234433                   0.0
# 1449              -51.8839              0.235113                   0.0
#
#       left_ground_force_pz  left_ground_torque_x  left_ground_torque_y  \
# 0                -0.975705               20.9838             -0.458886
# 1                -0.975311               20.9148             -0.452099
# 2                -0.975924               21.1226             -0.439515
# 3                -0.976401               21.0996             -0.455882
# 4                -0.975583               20.8899             -0.464569
# ...                    ...                   ...                   ...
# 1445             -0.983253               22.4194             -2.147650
# 1446             -0.982743               22.1088             -2.111910
# 1447             -0.982110               21.9007             -2.050860
# 1448             -0.983137               22.0181             -2.019220
# 1449             -0.982520               21.8327             -1.940320
#
#       left_ground_torque_z
# 0                  9.89021
# 1                  9.91327
# 2                  9.76921
# 3                  9.81639
# 4                 10.00380
# ...                    ...
# 1445              10.07330
# 1446              10.34690
# 1447              10.23740
# 1448              10.21740
# 1449              10.38320
#
# [1450 rows x 19 columns]
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\1_Hanif_Shallow_5_0_grf.mot (401 frames, 0.2-2.2s)
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\2_Hanif_Shallow_5_0_grf.mot (401 frames, 2.3-4.3s)
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\3_Hanif_Shallow_5_0_grf.mot (421 frames, 4.4-6.5s)
# All done!
#        time  right_ground_force_vx  right_ground_force_vy  \
# 0     0.000              -0.790975                287.559
# 1     0.005              -1.019820                286.877
# 2     0.010              -0.370098                285.884
# 3     0.015              -1.110470                285.385
# 4     0.020              -1.231380                284.925
# ...     ...                    ...                    ...
# 1751  8.755               0.997145                286.929
# 1752  8.760               1.025400                284.382
# 1753  8.765               1.102180                282.801
# 1754  8.770               1.020260                283.318
# 1755  8.775               0.997187                282.313
#
#       right_ground_force_vz  right_ground_force_px  right_ground_force_py  \
# 0                   61.3097               0.183106                    0.0
# 1                   61.4415               0.182592                    0.0
# 2                   61.5987               0.181536                    0.0
# 3                   61.2568               0.180936                    0.0
# 4                   61.0778               0.180523                    0.0
# ...                     ...                    ...                    ...
# 1751                62.9139               0.187014                    0.0
# 1752                63.2805               0.186848                    0.0
# 1753                63.5284               0.186881                    0.0
# 1754                62.8594               0.186747                    0.0
# 1755                62.6407               0.187073                    0.0
#
#       right_ground_force_pz  right_ground_torque_x  right_ground_torque_y  \
# 0                  -1.44567               -17.3441              -0.565534
# 1                  -1.44589               -17.2392              -0.591757
# 2                  -1.44719               -16.8097              -0.414505
# 3                  -1.44685               -16.8758              -0.321115
# 4                  -1.44695               -16.8174              -0.336023
# ...                     ...                    ...                    ...
# 1751               -1.44340               -17.9518               4.051000
# 1752               -1.44254               -18.0370               4.011090
# 1753               -1.44275               -17.8764               3.997520
# 1754               -1.44326               -17.7637               3.977780
# 1755               -1.44325               -17.7033               4.024270
#
#       right_ground_torque_z  left_ground_force_vx  left_ground_force_vy  \
# 0                  -5.18923               4.39478               311.903
# 1                  -5.33671               4.18558               314.081
# 2                  -5.60823               4.40863               313.637
# 3                  -5.74605               4.09921               316.962
# 4                  -5.86106               4.06550               316.608
# ...                     ...                   ...                   ...
# 1751               -3.03051              -7.20133               303.749
# 1752               -3.04744              -6.99371               302.828
# 1753               -3.01489              -7.02433               301.417
# 1754               -3.07127              -6.76951               300.843
# 1755               -2.95018              -7.00398               299.457
#
#       left_ground_force_vz  left_ground_force_px  left_ground_force_py  \
# 0                 -63.0322              0.187989                   0.0
# 1                 -63.3501              0.187536                   0.0
# 2                 -63.8451              0.186964                   0.0
# 3                 -64.0995              0.185871                   0.0
# 4                 -64.4222              0.186155                   0.0
# ...                    ...                   ...                   ...
# 1751              -64.0129              0.198069                   0.0
# 1752              -64.4279              0.198627                   0.0
# 1753              -63.1047              0.198339                   0.0
# 1754              -62.9058              0.198224                   0.0
# 1755              -62.8387              0.198281                   0.0
#
#       left_ground_force_pz  left_ground_torque_x  left_ground_torque_y  \
# 0                -0.960949               18.0384              -3.56349
# 1                -0.960467               18.0148              -3.63382
# 2                -0.959650               17.7315              -3.63514
# 3                -0.959010               17.7193              -3.73578
# 4                -0.959190               17.7562              -3.77883
# ...                    ...                   ...                   ...
# 1751             -0.969045               20.1615              -3.88113
# 1752             -0.969469               20.2282              -3.94025
# 1753             -0.970053               20.3102              -3.89785
# 1754             -0.969208               20.0148              -3.96191
# 1755             -0.969895               20.1332              -3.95607
#
#       left_ground_torque_z
# 0                -3.230600
# 1                -3.389660
# 2                -3.568910
# 3                -3.952350
# 4                -3.842360
# ...                    ...
# 1751              0.305556
# 1752              0.502575
# 1753              0.392007
# 1754              0.364500
# 1755              0.390907
#
# [1756 rows x 19 columns]
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\1_Hanif_Shallow_7_5_grf.mot (461 frames, 0.8-3.1s)
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\2_Hanif_Shallow_7_5_grf.mot (481 frames, 3.4-5.8s)
# Saved ..\Vicon Data\Shallow Squat\ID\GRF\3_Hanif_Shallow_7_5_grf.mot (481 frames, 6.1-8.5s)
# All done!
